# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

#load the dataset
df = pd.read_csv("../data/Tech_Use_Stress_Wellness.csv")

#find the shape and data types
print(df.shape)
print(df.info())
# Out:
# (5000, 25)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 25 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   user_id                           5000 non-null   int64
#  1   age                               5000 non-null   int64
#  2   gender                            5000 non-null   object
#  3   daily_screen_time_hours           5000 non-null   float64
#  4   phone_usage_hours                 5000 non-null   float64
#  5   laptop_usage_hours                5000 non-null   float64
#  6   tablet_usage_hours                5000 non-null   float64
#  7   tv_usage_hours                    5000 non-null   float64
#  8   social_media_hours                5000 non-null   float64
#  9   work_related_hours                5000 non-null   float64
#  10  entertainment_hours               5000 non-null   float64
#  11  gaming_hours                      5000 non-null   float64
#  12  sleep_duration_hours              5000 non-null   float64
#  13  sleep_quality                     5000 non-null   float64
#  14  mood_rating                       5000 non-null   float64
#  15  stress_level                      5000 non-null   int64
#  16  physical_activity_hours_per_week  5000 non-null   float64
#  17  location_type                     5000 non-null   object
#  18  mental_health_score               5000 non-null   float64
#  19  uses_wellness_apps                5000 non-null   bool
#  20  eats_healthy                      5000 non-null   bool
#  21  caffeine_intake_mg_per_day        5000 non-null   float64
#  22  weekly_anxiety_score              5000 non-null   float64
#  23  weekly_depression_score           5000 non-null   float64
#  24  mindfulness_minutes_per_day       5000 non-null   float64
# dtypes: bool(2), float64(18), int64(3), object(2)
# memory usage: 908.3+ KB
# None

# %%
# Summary statistics
print(df.describe())

# Check missing values
print(df.isna().sum())
# Out:
#            user_id         age  daily_screen_time_hours  phone_usage_hours  \
# count  5000.000000  5000.00000              5000.000000        5000.000000
# mean   2500.500000    44.70120                 5.037860           1.994400
# std    1443.520003    17.26688                 1.835637           0.890671
# min       1.000000    15.00000                 1.000000           0.200000
# 25%    1250.750000    30.00000                 3.700000           1.400000
# 50%    2500.500000    45.00000                 5.000000           2.000000
# 75%    3750.250000    60.00000                 6.300000           2.600000
# max    5000.000000    74.00000                10.000000           5.000000
#
#        laptop_usage_hours  tablet_usage_hours  tv_usage_hours  \
# count         5000.000000         5000.000000     5000.000000
# mean             1.555160            0.663060        1.433040
# std              1.025994            0.525438        0.928931
# min              0.000000            0.000000        0.000000
# 25%              0.700000            0.200000        0.700000
# 50%              1.500000            0.600000        1.400000
# 75%              2.300000            1.000000        2.100000
# max              5.000000            2.900000        4.000000
#
#        social_media_hours  work_related_hours  entertainment_hours  ...  \
# count         5000.000000         5000.000000          5000.000000  ...
# mean             3.276920            3.360240             1.662200  ...
# std              1.203655            0.827026             0.659647  ...
# min              0.300000            0.700000             0.000000  ...
# 25%              2.400000            3.100000             1.200000  ...
# 50%              3.600000            3.700000             1.600000  ...
# 75%              4.500000            3.900000             2.100000  ...
# max              4.500000            4.500000             3.900000  ...
#
#        sleep_duration_hours  sleep_quality  mood_rating  stress_level  \
# count           5000.000000    5000.000000  5000.000000   5000.000000
# mean               7.370080       4.009400     4.447900      5.718400
# std                0.543875       0.663777     2.768151      2.915064
# min                5.400000       1.000000     1.000000      1.000000
# 25%                7.000000       4.000000     1.700000      3.000000
# 50%                7.400000       4.000000     4.300000      6.000000
# 75%                7.700000       4.000000     6.700000      8.000000
# max                9.000000       5.000000    10.000000     10.000000
#
#        physical_activity_hours_per_week  mental_health_score  \
# count                        5000.00000          5000.000000
# mean                            2.65934            64.766200
# std                             2.28885            13.095779
# min                             0.00000            31.000000
# 25%                             0.60000            54.000000
# 50%                             2.30000            65.000000
# 75%                             4.20000            75.000000
# max                            11.80000           100.000000
#
#        caffeine_intake_mg_per_day  weekly_anxiety_score  \
# count                 5000.000000           5000.000000
# mean                   142.321260              8.631800
# std                     50.468392              5.092565
# min                      0.000000              0.000000
# 25%                    108.475000              5.000000
# 50%                    141.650000              8.000000
# 75%                    176.400000             12.000000
# max                    341.200000             21.000000
#
#        weekly_depression_score  mindfulness_minutes_per_day
# count              5000.000000                  5000.000000
# mean                  7.520000                    18.550820
# std                   4.672383                     7.992543
# min                   0.000000                     5.000000
# 25%                   4.000000                    12.400000
# 50%                   7.000000                    17.200000
# 75%                  11.000000                    23.800000
# max                  21.000000                    42.000000
#
# [8 rows x 21 columns]
# user_id                             0
# age                                 0
# gender                              0
# daily_screen_time_hours             0
# phone_usage_hours                   0
# laptop_usage_hours                  0
# tablet_usage_hours                  0
# tv_usage_hours                      0
# social_media_hours                  0
# work_related_hours                  0
# entertainment_hours                 0
# gaming_hours                        0
# sleep_duration_hours                0
# sleep_quality                       0
# mood_rating                         0
# stress_level                        0
# physical_activity_hours_per_week    0
# location_type                       0
# mental_health_score                 0
# uses_wellness_apps                  0
# eats_healthy                        0
# caffeine_intake_mg_per_day          0
# weekly_anxiety_score                0
# weekly_depression_score             0
# mindfulness_minutes_per_day         0
# dtype: int64

# %%
# Compare Work Related Hours with Stress Levels
plt.figure(figsize=(10, 6))
sns.scatterplot(data = df, x='work_related_hours', y='stress_level')
plt.title('Work Related Hours vs Stress Levels')
plt.xlabel('Work Related Hours')
plt.ylabel('Stress Levels')
plt.show()

# %%
# Compare Daily Screen Time Hours with Sleep hours
plt.figure(figsize=(10,6))
sns.scatterplot(data = df, x='daily_screen_time_hours', y='sleep_duration_hours')
plt.title('Daily Screen Time Hours vs Sleep Duration Hours')
plt.xlabel('Daily Screen Time Hours')
plt.ylabel('Sleep Duration Hours')
plt.show()

# %%
# Compare Social Media Hours with Mood rating
plt.figure(figsize=(10,6))
sns.histplot(data=df, x="social_media_hours", kde=True)
plt.title('Social Media Hours vs Mood Rating')
plt.xlabel('Social Media Hours')
plt.ylabel('Mood Rating')
plt.show()

# %%
# Compare gender with uses_wellness_apps
plt.figure(figsize=(10,6))
count_plot = sns.countplot(x="gender", hue="uses_wellness_apps", data=df)
count_plot.bar_label(count_plot.containers[0])
count_plot.bar_label(count_plot.containers[1])
plt.title('Which Gender uses wellness apps more?')
plt.xlabel('Gender')
plt.ylabel('Uses Wellness Apps')
plt.show()

# %%
# Compare Gaming Hours with weekly axiety score
joint_plot = sns.jointplot(x="gaming_hours", y="weekly_anxiety_score", data=df, kind="reg")
plt.xlabel('Gaming Hours')
plt.ylabel('Weekly Axiety Score')
plt.show()
